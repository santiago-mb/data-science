# %%
import scipy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
from scipy import io
from scipy import signal
import math
import sys
from IPython.display import display

# %% [markdown]
# ## Calcular la media entre los electrodos 8, 44, 80, 131 y 185 (el primer electrodo es el 0) y realizar una figura que muestre las frecuencias en el eje Y, los epochs en el eje X, y la potencia usando una escala de color

# %%
x = (sc.io.loadmat('datasetP/P02.mat'))['data']

epochs = len(x)
electrodes = 256
measures = 201

powersDF = None

plt.subplots(figsize=(20,5))

for i in range(epochs):
    epoch = pd.DataFrame(x[i])
    fourier = sc.signal.welch(epoch.loc[[7, 43, 79, 130, 184]].mean(), nperseg=measures, fs = 201)
    if powersDF is None:
        powersDF = pd.DataFrame(index = np.round(fourier[0], 2))
    powersDF[i] = pd.Series(fourier[1], index = powersDF.index)

sns.heatmap(powersDF[powersDF.index < 50], cmap = 'viridis', cbar_kws = {'label': r'$\frac{V^{2}}{Hz}$'})
plt.xlabel('Epochs')
plt.ylabel('Frecuencia (Hz)')
plt.title('Heatmap P02')
plt.show()

# %% [markdown]
# ## Calcular los valores de cada banda de frecuencia, promediados entre los electrodos (todos) y epochs para cada sujeto

# %%
deltaRange = [0.0, 4.0]
thetaRange = [4.0, 8.0]
alphaRange = [8.0, 13.0]
betaRange = [13.0, 30.0]
gammaRange = [30.0, 50.0]
classification = ['P'] * 10 + ['S'] * 10
names = list(map((lambda x: ('0'+ str(x))[-2:]), range(1,11)))
datasets = ['datasetP/P', 'datasetS/S']

meanDFs = []
subjectsDelta = []
subjectsTheta = []
subjectsAlpha = []
subjectsBeta = []
subjectsGamma = []
subjectsDeltaStDev = []
subjectsThetaStDev = []
subjectsAlphaStDev = []
subjectsBetaStDev = []
subjectsGammaStDev = []
bandNames = ['Delta', 'Theta', 'Alpha', 'Beta', 'Gamma']
bandNamesStDev = ['Delta stdev', 'Theta stdev', 'Alpha stdev', 'Beta stdev', 'Gamma stdev']

considerateInBins = []

df = pd.DataFrame(columns = bandNames + bandNamesStDev)

for dataset in datasets:
    for name in names:
        x = (sc.io.loadmat(dataset + name + '.mat'))['data']
        epochs = len(x)
        electrodes = 256
        measures = 201

        epochAcum = None
        epochAcumDF = None
        for i in range(epochs):
            dfe = pd.DataFrame(x[i])
            epoch = dfe.sum()
            if epochAcum is None:
                epochAcumDF = dfe
                epochAcum = epoch
            else:
                epochAcumDF = epochAcumDF.add(dfe)
                epochAcum = epochAcum.add(epoch)
            if np.random.random_sample() * 100 < 5:
                considerateInBins.append(dfe)
        
        epochAcum = epochAcum.divide(epochs * electrodes)
        epochAcumDF = epochAcumDF.divide(epochs)
        meanDFs.append(epochAcumDF)
        fourier = sc.signal.welch(epochAcum, nperseg=measures, fs = 201)
        frecs = fourier[0]
        powers = fourier[1]
        theta = next(i for i, v in enumerate(frecs) if v >= thetaRange[0] and v < thetaRange[1])
        alpha = next(i for i, v in enumerate(frecs) if v >= alphaRange[0] and v < alphaRange[1])
        beta = next(i for i, v in enumerate(frecs) if v >= betaRange[0] and v < betaRange[1])
        gamma = next(i for i, v in enumerate(frecs) if v >= gammaRange[0] and v < gammaRange[1])

        subjectsDelta.append(powers[:theta].mean())
        subjectsTheta.append(powers[theta:alpha].mean())
        subjectsAlpha.append(powers[alpha:beta].mean())
        subjectsBeta.append(powers[beta:gamma].mean())
        subjectsGamma.append(powers[gamma:].mean())

        subjectsDeltaStDev.append(powers[:theta].std())
        subjectsThetaStDev.append(powers[theta:alpha].std())
        subjectsAlphaStDev.append(powers[alpha:beta].std())
        subjectsBetaStDev.append(powers[beta:gamma].std())
        subjectsGammaStDev.append(powers[gamma:].std())

        index = len(subjectsDelta)
        df = df.append((pd.Series( \
            { \
                bandNames[0]: subjectsDelta[-1], \
                bandNames[1]: subjectsTheta[-1], \
                bandNames[2]: subjectsAlpha[-1], \
                bandNames[3]: subjectsBeta[-1], \
                bandNames[4]: subjectsGamma[-1], \
                bandNamesStDev[0]: subjectsDeltaStDev[-1], \
                bandNamesStDev[1]: subjectsThetaStDev[-1], \
                bandNamesStDev[2]: subjectsAlphaStDev[-1], \
                bandNamesStDev[3]: subjectsBetaStDev[-1], \
                bandNamesStDev[4]: subjectsGammaStDev[-1] \
            })).rename('Subject ' + names[(index - 1) % 10] + ' ' + classification[index - 1]))
display(df)
# df.to_csv('../tp3/mean-stdev-raw.csv')
# Out:
#                      Delta         Theta         Alpha          Beta  \
# Subject 01 P  1.933618e-17  8.238647e-17  4.174321e-18  1.170747e-18
# Subject 02 P  4.933276e-17  1.592153e-17  1.255062e-18  3.657378e-19
# Subject 03 P  8.579026e-17  8.927993e-18  2.530623e-18  7.835320e-19
# Subject 04 P  6.627825e-18  3.045901e-18  1.437712e-19  1.659174e-20
# Subject 05 P  6.515051e-17  3.555999e-16  3.639976e-17  1.450163e-17
# Subject 06 P  2.325545e-18  5.050404e-19  7.865331e-20  8.049402e-21
# Subject 07 P  5.181191e-17  8.452204e-17  1.780590e-17  8.251151e-19
# Subject 08 P  3.158920e-16  1.117502e-16  4.583215e-18  3.090276e-19
# Subject 09 P  8.936738e-15  2.633642e-15  2.294612e-16  9.710163e-16
# Subject 10 P  3.390567e-18  1.906765e-19  4.650550e-20  9.425921e-21
# Subject 01 S  1.810282e-17  4.389371e-18  4.055134e-19  9.856823e-20
# Subject 02 S  4.589841e-18  2.748827e-18  2.779170e-18  2.040427e-19
# Subject 03 S  4.896947e-18  9.779837e-18  3.085240e-18  9.700117e-20
# Subject 04 S  9.762127e-17  9.219905e-18  3.607218e-18  1.016120e-18
# Subject 05 S  2.298004e-18  6.241850e-18  2.968497e-19  2.868118e-20
# Subject 06 S  2.661719e-18  8.053801e-18  2.632099e-18  2.907836e-19
# Subject 07 S  1.000797e-15  3.325391e-18  4.295213e-18  1.130431e-18
# Subject 08 S  2.667993e-16  1.765546e-16  4.699488e-17  1.311014e-17
# Subject 09 S  9.501852e-15  5.938874e-16  2.613197e-15  7.992383e-16
# Subject 10 S  2.949129e-17  1.108041e-17  1.270402e-18  1.840776e-18
#
#                      Gamma   Delta stdev   Theta stdev   Alpha stdev  \
# Subject 01 P  5.460780e-20  1.142105e-17  6.589826e-17  2.710178e-18
# Subject 02 P  3.174904e-20  4.813444e-17  1.978622e-17  1.150244e-18
# Subject 03 P  3.328533e-20  9.794422e-17  6.492333e-18  1.402481e-18
# Subject 04 P  3.063610e-22  7.433970e-18  1.773314e-18  1.366289e-19
# Subject 05 P  3.942575e-19  5.277000e-17  2.226792e-16  2.514125e-17
# Subject 06 P  8.603865e-22  1.948442e-18  3.448960e-19  4.835214e-20
# Subject 07 P  3.350370e-20  6.014960e-17  6.458679e-17  1.591448e-17
# Subject 08 P  1.061924e-20  3.360102e-16  9.565384e-17  3.393934e-18
# Subject 09 P  3.550572e-17  6.820503e-15  2.063029e-15  1.090734e-16
# Subject 10 P  4.121588e-22  3.849416e-18  2.762696e-19  3.327891e-20
# Subject 01 S  7.259788e-21  1.537121e-17  7.030882e-19  2.849992e-19
# Subject 02 S  2.492486e-21  3.100218e-18  1.265984e-18  2.098524e-18
# Subject 03 S  3.849989e-21  3.196692e-18  6.735911e-18  3.322949e-18
# Subject 04 S  6.517223e-20  6.469994e-17  8.681492e-18  2.254079e-18
# Subject 05 S  3.003176e-22  3.140604e-18  4.012368e-18  1.808257e-19
# Subject 06 S  1.800315e-20  2.059962e-18  4.220440e-18  1.207451e-18
# Subject 07 S  6.517585e-20  9.973983e-16  2.907777e-18  2.110550e-18
# Subject 08 S  1.671221e-19  1.322902e-16  1.204186e-16  3.923009e-17
# Subject 09 S  7.233109e-17  6.937876e-15  3.760993e-16  1.830232e-15
# Subject 10 S  8.327010e-20  2.049922e-17  7.354764e-18  4.532496e-19
#
#                 Beta stdev   Gamma stdev
# Subject 01 P  8.936329e-19  1.863571e-19
# Subject 02 P  2.859566e-19  1.166969e-19
# Subject 03 P  7.929307e-19  1.504384e-19
# Subject 04 P  1.500193e-20  9.685074e-22
# Subject 05 P  1.591116e-17  1.636181e-18
# Subject 06 P  6.797363e-21  3.381717e-21
# Subject 07 P  1.064565e-18  1.135538e-19
# Subject 08 P  2.014890e-19  3.483724e-20
# Subject 09 P  1.146969e-15  1.689142e-16
# Subject 10 P  8.191413e-21  1.356825e-21
# Subject 01 S  9.425335e-20  2.040701e-20
# Subject 02 S  2.425561e-19  1.005397e-20
# Subject 03 S  1.294807e-19  1.750115e-20
# Subject 04 S  6.602787e-19  1.936986e-19
# Subject 05 S  2.589179e-20  1.342715e-21
# Subject 06 S  2.806569e-19  7.715031e-20
# Subject 07 S  8.663553e-19  2.373976e-19
# Subject 08 S  8.867136e-18  7.000871e-19
# Subject 09 S  9.180021e-16  3.313112e-16
# Subject 10 S  1.272758e-18  2.175496e-19

# %% [markdown]
# ## Tomar la potencia de cada sujeto en la banda Alpha y graficar cada uno de los graficos categóricos de seaborn

# %%
df = pd.DataFrame({'P': subjectsAlpha[:10], 'S': subjectsAlpha[10:]})
plotNames = ['StripPlot', 'SwarmPlot', 'BoxPlot', 'ViolinPlot', 'LVPlot', 'PointPlot', 'BarPlot', 'CountPlot']
plots = [sns.stripplot, sns.swarmplot, sns.boxplot, sns.violinplot, sns.lvplot, sns.pointplot, sns.barplot]

for i, plotClass in enumerate(plots):
    fig = plotClass(data = df)
    if (i < 2):
        fig.set_ylim([0, df['P'].max() * 1.1])
    plt.title(plotNames[i] + ' Alpha Band')
    plt.show()

df_new = pd.DataFrame({'class': ['P'] * 10 + ['S'] * 10, 'values': subjectsAlpha})
sns.countplot(x = 'class', data = df_new)
plt.title(plotNames[-1])
plt.show()

# %% [markdown]
# ## ¿Cuál recomendaría para graficar y comparar distribuciones?
# Para comparar las distribuciones recomendamos utilizar violin plot. En este gráfico se visualiza la distribución de los datos y su probabilidad de densidad, ya que es una combinación entre un density plot y un box plot. En el primer tipo de gráfico vemos la distrubición de los datos, mientras que el segundo nos da información sobre la media y outliers (entre otros).
#
# En un violin plot, las secciones más anchas representan mayor probabilidad de que los datos se ubiquen en dicha región; las secciones más angostas señalan una menor probablidad de que esto suceda.
#
# Podemos observar que la banda de frecuencia alfa para la categoría de pacientes S presenta datos anómalos de mayor valor que los pacientes P, mientras que en estos últimos la probabilidad de que la potencia de los electrodos esté en la región determinada por la media es más alta que en la categoría S (aquí las potencias están más distribuidas). Podemos suponer que la media (representada por el punto blanco) de ambas categorías para la banda alfa es similar, mientras que la varianza es distinta (pues las regiones tienen diferentes proporciones).

# %% [markdown]
# ## Para cada banda de frecuencia, graficarla y realizar un test estadístico apropiado

# %% [markdown]
# Como mencionamos en el item anterior, consideramos que el violin plot es el gráfico más adecuado para nuestro análisis. Además, al pie de cada uno, mostramos el resultado de haber ejecutado los tests de Kolmogorov-Smirnov en 2 muestras y One-way Anova, sobre cada una de las bandas.
#
# El test de Kolmogorov-Smirnov evalúa si dos muestras provienen de la misma distribución, por lo que si obtenemos un p-value alto, no podemos rechazar la hipótesis de que las distribuciones sean iguales. Para el caso de one-way Anova, el objetivo es rechazar que las muestras P y S tienen igual media.

# %%
formula = 'Value ~ C(Band) + C(Type) + C(Band):C(Type)'
subjectsBands = [subjectsDelta, subjectsTheta, subjectsAlpha, subjectsBeta, subjectsGamma]
subjectsBandsStDev = [subjectsDeltaStDev, subjectsThetaStDev, subjectsAlphaStDev, subjectsBetaStDev, subjectsGammaStDev]
testResultNames = ['Statistic', 'p-value'] 

dfGeneral = pd.DataFrame()
for i, subjectsBand in enumerate(subjectsBands):
    testResults = []
    dfTest = pd.DataFrame(columns = testResultNames)
    df = pd.DataFrame({'P': subjectsBand[:10], 'S': subjectsBand[10:]})
    sns.violinplot(data = df)
    plt.title('ViolinPlot ' + bandNames[i])
    plt.show()
    
    t, p = sc.stats.ks_2samp(df['P'], df['S'])
    testResults.append({'name': 'Kolmogorov-Smirnov','statistic': t, 'p-value': p})
    s, p = sc.stats.f_oneway(df['P'], df['S'])
    testResults.append({'name': 'One-Way Anova', 'statistic': s, 'p-value': p})
    
    for i in range(len(testResults)):
        dfTest = dfTest.append((pd.Series( \
        { \
            testResultNames[0]: testResults[i]['statistic'], \
            testResultNames[1]: testResults[i]['p-value'], \
        })).rename(testResults[i]['name']))

    display(dfTest)
# Out:
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.200000  0.974789
# One-Way Anova        0.011614  0.915373
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.400000  0.312853
# One-Way Anova        0.869815  0.363349
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.300000  0.675078
# One-Way Anova        0.829156  0.374550
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.300000  0.675078
# One-Way Anova        0.018773  0.892540
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.300000  0.675078
# One-Way Anova        0.207559  0.654136

# %% [markdown]
# Como puede observarse, los _p-valores_ correspondientes a ambos tests no fueron lo suficientemente pequeños como
# para rechazar las hipótesis nulas correspondientes. Es decir, no tenemos suficiente evidencia para decir que las bandas de frecuencia tienen distintas distribuciones, ni distintas medias.

# %% [markdown]
# ## Repetir para los valores normalizados
# ### 1) Calcular los valores de cada banda de frecuencia, promediados entre los electrodos (todos) y epochs para cada sujeto
# ### 2) Para cada banda de frecuencia, graficarla y realizar un test estadístico apropiado

# %% [markdown]
# Al igual que el ejercicio previo, primero presentamos una tabla con las medias y stdev de las frecuencias para cada banda y sujeto a través de violin plots, y al pie de cada uno, una tabla indicando los resultados de cada test
# estadístico.

# %%
normalizedDelta = []
normalizedTheta = []
normalizedAlpha = []
normalizedBeta = []
normalizedGamma = []
normalizedBands = [normalizedDelta, normalizedTheta, normalizedAlpha, normalizedBeta, normalizedGamma]
normalizedDeltaStDev = []
normalizedThetaStDev = []
normalizedAlphaStDev = []
normalizedBetaStDev = []
normalizedGammaStDev = []
normalizedBandsStDev = [normalizedDeltaStDev, normalizedThetaStDev, normalizedAlphaStDev, normalizedBetaStDev, normalizedGammaStDev]

df = pd.DataFrame(columns = bandNames + bandNamesStDev)

for i, _ in enumerate(subjectsDelta):
    totalSum = 0
    for subjectsBand in subjectsBands:
        totalSum += subjectsBand[i]
    for j, normalizedBand in enumerate(normalizedBands):
        normalizedBand.append(subjectsBands[j][i] / float(totalSum))

    for subjectsBandStDev in subjectsBandsStDev:
        totalSum += subjectsBandStDev[i]
    for j, normalizedBandStDev in enumerate(normalizedBandsStDev):
        normalizedBandStDev.append(subjectsBandsStDev[j][i] / float(totalSum))

for i in range(len(normalizedBands[0])):
    df = df.append((pd.Series( \
        { \
            bandNames[0]: normalizedDelta[i], \
            bandNames[1]: normalizedTheta[i], \
            bandNames[2]: normalizedAlpha[i], \
            bandNames[3]: normalizedBeta[i], \
            bandNames[4]: normalizedGamma[i], \
            bandNamesStDev[0]: normalizedDeltaStDev[i], \
            bandNamesStDev[1]: normalizedThetaStDev[i], \
            bandNamesStDev[2]: normalizedAlphaStDev[i], \
            bandNamesStDev[3]: normalizedBetaStDev[i], \
            bandNamesStDev[4]: normalizedGammaStDev[i] \
        })).rename('Subject ' + names[i % 10] + ' ' + classification[i]))

display(df)
# df.to_csv('../tp3/mean-stdev-norm.csv')
# Out:
#                  Delta     Theta     Alpha      Beta     Gamma  Delta stdev  \
# Subject 01 P  0.180506  0.769088  0.038968  0.010929  0.000510     0.060675
# Subject 02 P  0.737335  0.237966  0.018758  0.005466  0.000475     0.352943
# Subject 03 P  0.874824  0.091041  0.025805  0.007990  0.000339     0.478131
# Subject 04 P  0.673943  0.309719  0.014619  0.001687  0.000031     0.387301
# Subject 05 P  0.138017  0.753316  0.077111  0.030721  0.000835     0.066782
# Subject 06 P  0.796925  0.173069  0.026953  0.002758  0.000295     0.369722
# Subject 07 P  0.334274  0.545309  0.114878  0.005323  0.000216     0.202642
# Subject 08 P  0.730310  0.258355  0.010596  0.000714  0.000025     0.387180
# Subject 09 P  0.697836  0.205651  0.017918  0.075823  0.002773     0.295070
# Subject 10 P  0.932092  0.052418  0.012785  0.002591  0.000113     0.493129
# Subject 01 S  0.786958  0.190813  0.017628  0.004285  0.000316     0.389367
# Subject 02 S  0.444564  0.266246  0.269185  0.019763  0.000241     0.181919
# Subject 03 S  0.274141  0.547495  0.172718  0.005430  0.000216     0.102244
# Subject 04 S  0.875294  0.082668  0.032343  0.009111  0.000584     0.344114
# Subject 05 S  0.259202  0.704046  0.033483  0.003235  0.000034     0.193545
# Subject 06 S  0.194906  0.589745  0.192737  0.021293  0.001318     0.095803
# Subject 07 S  0.991268  0.003294  0.004254  0.001120  0.000065     0.495446
# Subject 08 S  0.529757  0.350567  0.093313  0.026031  0.000332     0.164309
# Subject 09 S  0.699668  0.043731  0.192423  0.058852  0.005326     0.289391
# Subject 10 S  0.673838  0.253173  0.029027  0.042059  0.001903     0.278659
#
#               Theta stdev  Alpha stdev  Beta stdev  Gamma stdev
# Subject 01 P     0.350091     0.014398    0.004748     0.000990
# Subject 02 P     0.145081     0.008434    0.002097     0.000856
# Subject 03 P     0.031693     0.006846    0.003871     0.000734
# Subject 04 P     0.092388     0.007118    0.000782     0.000050
# Subject 05 P     0.281807     0.031817    0.020136     0.002071
# Subject 06 P     0.065445     0.009175    0.001290     0.000642
# Subject 07 P     0.217590     0.053615    0.003586     0.000383
# Subject 08 P     0.110221     0.003911    0.000232     0.000040
# Subject 09 P     0.089251     0.004719    0.049620     0.007308
# Subject 10 P     0.035392     0.004263    0.001049     0.000174
# Subject 01 S     0.017810     0.007219    0.002388     0.000517
# Subject 02 S     0.074287     0.123140    0.014233     0.000590
# Subject 03 S     0.215443     0.106282    0.004141     0.000560
# Subject 04 S     0.046173     0.011989    0.003512     0.001030
# Subject 05 S     0.247269     0.011144    0.001596     0.000083
# Subject 06 S     0.196281     0.056155    0.013053     0.003588
# Subject 07 S     0.001444     0.001048    0.000430     0.000118
# Subject 08 S     0.149564     0.048725    0.011013     0.000870
# Subject 09 S     0.015688     0.076342    0.038292     0.013820
# Subject 10 S     0.099978     0.006161    0.017301     0.002957

# %%
dfGeneral = pd.DataFrame()
for i, normalizedBand in enumerate(normalizedBands):
    testResults = []
    dfTest = pd.DataFrame(columns = testResultNames)
    df = pd.DataFrame({'P': normalizedBand[:10], 'S': normalizedBand[10:]})
    sns.violinplot(data = df)
    plt.title('ViolinPlot Normalized ' + bandNames[i])
    plt.show()

    t, p = sc.stats.ks_2samp(df['P'], df['S'])
    testResults.append({'name': 'Kolmogorov-Smirnov','statistic': t, 'p-value': p})
    s, p = sc.stats.f_oneway(df['P'], df['S'])
    testResults.append({'name': 'One-Way Anova', 'statistic': s, 'p-value': p})
    
    for i in range(len(testResults)):
        dfTest = dfTest.append((pd.Series( \
        { \
            testResultNames[0]: testResults[i]['statistic'], \
            testResultNames[1]: testResults[i]['p-value'], \
        })).rename(testResults[i]['name']))

    display(dfTest)
# Out:
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.300000  0.675078
# One-Way Anova        0.084999  0.773967
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.200000  0.974789
# One-Way Anova        0.105356  0.749236
#                     Statistic  p-value
# Kolmogorov-Smirnov    0.50000  0.11084
# One-Way Anova         4.53984  0.04716
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.300000  0.675078
# One-Way Anova        0.246672  0.625439
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.200000  0.974789
# One-Way Anova        0.676095  0.421694

# %% [markdown]
# Al igual que en la sección anterior, ningún test nos permite decir que las bandas de frecuencia tengan distintas distribuciones ni distintas medias.

# %% [markdown]
# ## Computar una medida de información intra-electrodo. Calcular la media entre canales y epochs para cada sujeto. Realizar el gráfico elegido en la sección anterior, acompañado del test estadístico apropiado

# %%
def scottRule(powers):
    ampMax = max(powers)
    ampMin = min(powers)
    interval = ampMax-ampMin
    n = math.ceil(float(interval) / (3.5 * np.std(powers) * (len(powers) ** (-1 / 3.0))))
    return n, float(interval) / n

nMean = None
nAcum = []
maxAcum = []
minAcum = []
for epoch in considerateInBins:
    fourier = sc.signal.welch(epoch, nperseg=measures, fs = 201)
    for f in fourier[1]:
        n, _ = scottRule(powers)
        nAcum.append(n)
        maxAcum.append(max(f))
        minAcum.append(min(f))
nMean = np.mean(nAcum)
maxPower = np.mean(maxAcum)
minPower = np.mean(minAcum)

# %% [markdown]
# Habiendo corrido varias veces la regla de Scott para encontrar un buen valor para la cantidad de Bins a utilizar, los resultados que fuimos obteniendo no nos resultaron razonables, ya que la distribución de los bines al discretizar las frecuencias, no era nada uniforme (mayormente habia muchos ceros, por ejemplo). Haciendo algunos testeos manuales, decidimos fijar el número de Bins en 1000, porque mostraba una distribución un poco mejor.

# %%
interval = maxPower - minPower
var = nMean
nMean = 1000
step = interval / nMean

def bineador(power):
    val = int(power / step)
    if val > nMean - 1:
        return int(nMean - 1)
    return val

dfEntropies = None
for it, meanEpoch in enumerate(meanDFs):
    fourier = sc.signal.welch(meanEpoch, nperseg=measures, fs = 201)
    entropiesByElectrode = []
    for powers in fourier[1]:
        series = list(map(bineador, powers))
        probabilityOfXs = [(series.count(i)/float(len(series))) for i in list(range(int(nMean)))]
        entropy = sc.stats.entropy(probabilityOfXs)
        entropiesByElectrode.append(entropy)
    dfAux = pd.DataFrame({classification[it] + str(it % 10): entropiesByElectrode})
    if dfEntropies is None:
        dfEntropies = dfAux
    else:
        dfEntropies[classification[it] + str(it % 10)] = dfAux

# %% [markdown]
# A continuación, con los cálculos realizados previamente, por medio de violin plots mostraremos la distribución de los datos. Además, realizaremos tests estadísticos utilizando Kolmogorov-Smirnov y One-Way Anova nuevamente.

# %%
plt.subplots(figsize = (20,5))
sns.violinplot(data = dfEntropies)
plt.title('Entropies By Subject')
plt.show()

dfMean = dfEntropies.mean()

dfMeanPAux = dfMean[:10].reset_index(drop = True)
dfMeanSAux = dfMean[10:].reset_index(drop = True)

dfMeanEntropy = pd.DataFrame({'P': dfMeanPAux, 'S': dfMeanSAux})

sns.violinplot(data = dfMeanEntropy)
plt.title('Mean Entropies Per Subject By Category')
plt.show()

testResults = []
dfTest = pd.DataFrame(columns = testResultNames)

t, p = sc.stats.ks_2samp(dfMeanEntropy['P'], dfMeanEntropy['S'])
testResults.append({'name': 'Kolmogorov-Smirnov','statistic': t, 'p-value': p})

s, p = sc.stats.f_oneway(dfMeanEntropy['P'], dfMeanEntropy['S'])
testResults.append({'name': 'One-Way Anova', 'statistic': s, 'p-value': p})

for i in range(len(testResults)):
        dfTest = dfTest.append((pd.Series( \
        { \
            testResultNames[0]: testResults[i]['statistic'], \
            testResultNames[1]: testResults[i]['p-value'], \
        })).rename(testResults[i]['name']))

display(dfTest)

meanElectrodesEntropyP = dfEntropies[['P0','P1','P2','P3','P4','P5','P6','P7','P8','P9']].T.mean()
meanElectrodesEntropyS = dfEntropies[['S0','S1','S2','S3','S4','S5','S6','S7','S8','S9']].T.mean()

dfMeanEntropy = pd.DataFrame({'P': meanElectrodesEntropyP, 'S': meanElectrodesEntropyS})
sns.violinplot(data = dfMeanEntropy)
plt.title('Mean Electrodes Entropies By Category')
plt.show()

testResults = []
dfTest = pd.DataFrame(columns = testResultNames)
t, p = sc.stats.ks_2samp(dfMeanEntropy['P'], dfMeanEntropy['S'])
testResults.append({'name': 'Kolmogorov-Smirnov','statistic': t, 'p-value': p})

s, p = sc.stats.f_oneway(dfMeanEntropy['P'], dfMeanEntropy['S'])
testResults.append({'name': 'One-Way Anova', 'statistic': s, 'p-value': p})

for i in range(len(testResults)):
        dfTest = dfTest.append((pd.Series( \
        { \
            testResultNames[0]: testResults[i]['statistic'], \
            testResultNames[1]: testResults[i]['p-value'], \
        })).rename(testResults[i]['name']))

display(dfTest)
# Out:
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.200000  0.974789
# One-Way Anova        0.099124  0.756504
#                     Statistic       p-value
# Kolmogorov-Smirnov   0.246094  2.585098e-07
# One-Way Anova        6.971841  8.534000e-03

# %% [markdown]
# En el primer par de tests, intentamos rechazar las hipótesis de que los promedios de las entropías intra-electrodo para cada clase de sujetos tienen iguales distribuciones y medias. Ambos tests nos dicen que no tenemos suficiente información para rechazar estas hipótesis.
# Por otro lado, el segundo par de tests nos permite afirmar que las medias de los electrodos para las clases P y S son distintas, y que sus distribuciones también lo son.

# %% [markdown]
# Por último, la siguiente tabla describe los valores de la media y stdev de la medida de información intra-electrodo.

# %%
means = dfEntropies.mean()
stDevs = dfEntropies.std()
df = pd.DataFrame({'Mean': means, 'StDev': stDevs})
display(df)
# df.to_csv('../tp3/mean-stdev-intra.csv')
# Out:
#         Mean     StDev
# P0  0.224696  0.084348
# P1  0.058053  0.059962
# P2  0.324914  0.125720
# P3  0.076737  0.048177
# P4  0.307805  0.098581
# P5  0.109697  0.069351
# P6  0.297163  0.097298
# P7  0.180409  0.101454
# P8  0.499774  0.206781
# P9  0.183743  0.064922
# S0  0.152830  0.152938
# S1  0.417469  0.159001
# S2  0.235634  0.119371
# S3  0.202179  0.151174
# S4  0.303734  0.091186
# S5  0.291524  0.098364
# S6  0.155629  0.095931
# S7  0.326383  0.164673
# S8  0.092931  0.128919
# S9  0.249901  0.160573

# %% [markdown]
# ## Repetir para una medida inter-electrodo

# %%
dfJointEntropies = None
chosenElectrodesForJointEntropy = [7, 43, 79, 130, 184]
binPairs = []
for i in range(nMean):
    for j in range(nMean):
        binPairs.append((i,j))

dfJointEntropies = None
for it, meanEpoch in enumerate(meanDFs):
    fourier = sc.signal.welch(meanEpoch.loc[chosenElectrodesForJointEntropy], nperseg=measures, fs = 201)
    
    entropiesByPair = []
    for i in range(len(chosenElectrodesForJointEntropy)):
        for j in range(i+1, len(chosenElectrodesForJointEntropy)):
            powersElectrodeX = fourier[1][i]
            powersElectrodeY = fourier[1][j]

            seriesX = list(map(bineador, powersElectrodeX))
            seriesY = list(map(bineador, powersElectrodeY))
            jointSeries = list(zip(seriesX, seriesY))
            jointProbability = [(jointSeries.count(p)/float(len(jointSeries))) for p in binPairs]
            entropy = sc.stats.entropy(jointProbability)
            entropiesByPair.append(entropy)
        
    dfAux = pd.DataFrame({classification[it] + str(it % 10): entropiesByPair})
    if dfJointEntropies is None:
        dfJointEntropies = dfAux
    else:
        dfJointEntropies[classification[it] + str(it % 10)] = dfAux

display(dfJointEntropies)
# Out:
#         P0        P1        P2        P3        P4        P5        P6  \
# 0  0.27673  0.055546  0.441539  0.000000  0.427813  0.221586  0.276730
# 1  0.27673  0.055546  0.441539  0.055546  0.427813  0.221586  0.331771
# 2  0.27673  0.055546  0.482538  0.000000  0.427813  0.166340  0.331771
# 3  0.27673  0.055546  0.482538  0.055546  0.496264  0.166340  0.331771
# 4  0.27673  0.055546  0.482538  0.055546  0.331771  0.221586  0.331771
# 5  0.27673  0.055546  0.482538  0.000000  0.331771  0.221586  0.331771
# 6  0.27673  0.055546  0.496264  0.055546  0.482538  0.221586  0.331771
# 7  0.27673  0.000000  0.386708  0.055546  0.331771  0.207861  0.331771
# 8  0.27673  0.000000  0.482538  0.055546  0.482538  0.221586  0.331771
# 9  0.27673  0.000000  0.482538  0.055546  0.482538  0.166340  0.331771
#
#          P7        P8        P9        S0        S1        S2        S3  \
# 0  0.331771  0.441539  0.331771  0.318045  0.572757  0.400362  0.166340
# 1  0.285413  0.427813  0.304320  0.318045  0.702985  0.400362  0.230372
# 2  0.331771  0.427813  0.318045  0.304320  0.572757  0.400362  0.299139
# 3  0.304320  0.441539  0.318045  0.304320  0.572757  0.427813  0.055546
# 4  0.331771  0.441539  0.263004  0.318045  0.518249  0.400362  0.263004
# 5  0.331771  0.386708  0.372982  0.299139  0.386708  0.400362  0.299139
# 6  0.331771  0.386708  0.372982  0.318045  0.441539  0.427813  0.166340
# 7  0.207861  0.427813  0.244098  0.207861  0.518249  0.133708  0.318045
# 8  0.207861  0.441539  0.318045  0.263004  0.572757  0.331805  0.244098
# 9  0.276730  0.386708  0.318045  0.249279  0.427813  0.331805  0.299139
#
#          S4        S5        S6        S7        S8        S9
# 0  0.463632  0.318045  0.110993  0.372982  0.207861  0.613430
# 1  0.482538  0.482538  0.244098  0.441539  0.207861  0.627155
# 2  0.482538  0.550486  0.221586  0.537155  0.207861  0.627155
# 3  0.331771  0.372982  0.249279  0.537155  0.207861  0.613430
# 4  0.482538  0.482538  0.263004  0.386708  0.055546  0.386708
# 5  0.482538  0.550486  0.263004  0.482538  0.055546  0.386708
# 6  0.463632  0.372982  0.249279  0.482538  0.055546  0.359256
# 7  0.482538  0.455087  0.221586  0.449906  0.000000  0.386708
# 8  0.482538  0.468812  0.263004  0.496264  0.000000  0.386708
# 9  0.482538  0.518249  0.263004  0.550881  0.000000  0.386708

# %%
plt.subplots(figsize = (20,5))
sns.violinplot(data = dfJointEntropies)
plt.title('Entropies By Subject')
plt.show()

dfJointMean = dfJointEntropies.mean()

dfJointMeanPAux = dfJointMean[:10].reset_index(drop = True)
dfJointMeanSAux = dfJointMean[10:].reset_index(drop = True)

dfMeanJointEntropy = pd.DataFrame({'P': dfJointMeanPAux, 'S': dfJointMeanSAux})

sns.violinplot(data = dfMeanJointEntropy)
plt.title('Mean Entropies Per Subject By Category')
plt.show()

testResultsJoint = []
dfTestJoint = pd.DataFrame(columns = testResultNames)

t, p = sc.stats.ks_2samp(dfMeanJointEntropy['P'], dfMeanJointEntropy['S'])
testResultsJoint.append({'name': 'Kolmogorov-Smirnov','statistic': t, 'p-value': p})

s, p = sc.stats.f_oneway(dfMeanJointEntropy['P'], dfMeanJointEntropy['S'])
testResultsJoint.append({'name': 'One-Way Anova', 'statistic': s, 'p-value': p})

for i in range(len(testResultsJoint)):
        dfTestJoint = dfTestJoint.append((pd.Series( \
        { \
            testResultNames[0]: testResultsJoint[i]['statistic'], \
            testResultNames[1]: testResultsJoint[i]['p-value'], \
        })).rename(testResultsJoint[i]['name']))

display(dfTestJoint)

meanElectrodesJointEntropyP = dfJointEntropies[['P0','P1','P2','P3','P4','P5','P6','P7','P8','P9']].T.mean()
meanElectrodesJointEntropyS = dfJointEntropies[['S0','S1','S2','S3','S4','S5','S6','S7','S8','S9']].T.mean()

dfMeanJointEntropy = pd.DataFrame({'P': meanElectrodesJointEntropyP, 'S': meanElectrodesJointEntropyS})
sns.violinplot(data = dfMeanJointEntropy)
plt.title('Mean Electrodes Entropies By Category')
plt.show()

testResultsJoint = []
dfTestJoint = pd.DataFrame(columns = testResultNames)
t, p = sc.stats.ks_2samp(dfMeanJointEntropy['P'], dfMeanJointEntropy['S'])
testResultsJoint.append({'name': 'Kolmogorov-Smirnov','statistic': t, 'p-value': p})

s, p = sc.stats.f_oneway(dfMeanJointEntropy['P'], dfMeanJointEntropy['S'])
testResultsJoint.append({'name': 'One-Way Anova', 'statistic': s, 'p-value': p})

for i in range(len(testResultsJoint)):
        dfTestJoint = dfTestJoint.append((pd.Series( \
        { \
            testResultNames[0]: testResultsJoint[i]['statistic'], \
            testResultNames[1]: testResultsJoint[i]['p-value'], \
        })).rename(testResultsJoint[i]['name']))

display(dfTestJoint)
# Out:
#                     Statistic   p-value
# Kolmogorov-Smirnov   0.400000  0.312853
# One-Way Anova        1.596657  0.222499
#                     Statistic       p-value
# Kolmogorov-Smirnov   1.000000  1.887979e-05
# One-Way Anova       55.328619  6.801489e-07

# %% [markdown]
# Aquí, las conclusiones son análogas a las de las medidas intra-electrodo: en el primer caso, no podemos rechazar que los promedios de las entropías conjuntas para los pares de electrodos elegidos, tengan igual media y distribución para las distintas clases de sujetos; mientras que sí podemos afirmar que entre las clases P y S, hay pares cuyas medias y distribuciones son distintas para cada tipo de sujeto.

# %%
means = dfJointEntropies.mean()
stDevs = dfJointEntropies.std()
df = pd.DataFrame({'Mean': means, 'StDev': stDevs})
display(df)
# df.to_csv('../tp3/mean-stdev-inter.csv')
# Out:
#         Mean         StDev
# P0  0.276730  5.851389e-17
# P1  0.038882  2.683130e-02
# P2  0.466128  3.340115e-02
# P3  0.038882  2.683130e-02
# P4  0.422263  6.752293e-02
# P5  0.203640  2.608541e-02
# P6  0.326267  1.740543e-02
# P7  0.294104  4.994621e-02
# P8  0.420972  2.439156e-02
# P9  0.316134  4.065298e-02
# S0  0.290010  3.767351e-02
# S1  0.528657  9.207179e-02
# S2  0.365475  8.809133e-02
# S3  0.234116  8.283223e-02
# S4  0.463680  4.700986e-02
# S5  0.457221  7.895455e-02
# S6  0.234884  4.638603e-02
# S7  0.473766  6.145241e-02
# S8  0.099808  9.572162e-02
# S9  0.477396  1.233537e-01
